# %%
import twint
import pandas as pd
from collections import Counter
import nest_asyncio
nest_asyncio.apply()

# %%
c = twint.Config()
c.Pandas = True
c.Search = "#dewa_kipas"
c.Limit = 1000
c.Lang = 'id'

# %%
twint.run.Search(c)
# Out:
# 1374976660072656899 2021-03-25 13:49:16 +0700 <2000rikka> Jika kopi hitamku ku sruput maka king mu berujung maut - Best Quotes #Dewa_Kipas  https://t.co/Wu3NNY8IYk
# 1374932074520477697 2021-03-25 10:52:06 +0700 <JoniKetapang> #IRENEWeek #irenesukandar #Dewa_Kipas #Chess #IkatanCintaEp214
# 1374709293283299332 2021-03-24 20:06:51 +0700 <IrmanBunawolo> @idextratime Grandmaster Irene Akui Pak Dadang Jago Main Catur, Pak Dadang Dewa Kipas: Berkat Mbak Iren, Ada Ada Rejeki  https://t.co/zWSmM25vvo  #DewaKipas  #dewa_kipas  #pakdadang  #GothamChess  #dewakipasVSgmirene
# 1374709191609262084 2021-03-24 20:06:26 +0700 <IrmanBunawolo> @ladazaa Grandmaster Irene Akui Pak Dadang Jago Main Catur, Pak Dadang Dewa Kipas: Berkat Mbak Iren, Ada Ada Rejeki  https://t.co/zWSmM25vvo  #DewaKipas  #dewa_kipas  #pakdadang  #GothamChess  #dewakipasVSgmirene
# ...

# %%
# Quick check
df = twint.storage.panda.Tweets_df
df.head()
# Out:
#                     id      conversation_id    created_at  \
# 0  1374976660072656899  1374976660072656899  1.616655e+12
# 1  1374932074520477697  1374931632688308224  1.616644e+12
# 2  1374709293283299332  1373940704636936196  1.616591e+12
# 3  1374709191609262084  1373930862388072451  1.616591e+12
# 4  1374709094804725764  1374011644154540039  1.616591e+12
#
#                   date timezone place  \
# 0  2021-03-25 13:49:16    +0700
# 1  2021-03-25 10:52:06    +0700
# 2  2021-03-24 20:06:51    +0700
# 3  2021-03-24 20:06:26    +0700
# 4  2021-03-24 20:06:03    +0700
#
#                                                tweet language  \
# 0  Jika kopi hitamku ku sruput maka king mu beruj...       in
# 1  #IRENEWeek #irenesukandar #Dewa_Kipas #Chess #...      und
# 2  @idextratime Grandmaster Irene Akui Pak Dadang...       in
# 3  @ladazaa Grandmaster Irene Akui Pak Dadang Jag...       in
# 4  @txtdariperokok Grandmaster Irene Akui Pak Dad...       in
#
# ...

# %%
df.to_csv('tweetResult.csv')
